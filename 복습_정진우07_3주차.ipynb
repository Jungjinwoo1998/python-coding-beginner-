# %%
import seaborn as sns
tt=sns.load_dataset('titanic')

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt['sex'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: sex
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
tt['sex','age'].info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sex', 'age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tt['sex','age'].info()
#
# ...

# %%
tt.query('age==22')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 60          0       3    male  22.0      0      0    7.2292        C   Third
# 80          0       3    male  22.0      0      0    9.0000        S   Third
# 112         0       3    male  22.0      0      0    8.0500        S   Third
# 141         1       3  female  22.0      0      0    7.7500        S   Third
# 151         1       1  female  22.0      1      0   66.6000        S   First
# 212         0       3    male  22.0      0      0    7.2500        S   Third
# 225         0       3    male  22.0      0      0    9.3500        S   Third
# 243         0       3    male  22.0      0      0    7.1250        S   Third
# 287         0       3    male  22.0      0      0    7.8958        S   Third
# 289         1       3  female  22.0      0      0    7.7500        Q   Third
# ...

# %%
#no data
tt.query('fare==8')
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
tt.query("sex=='female'")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query('fare >=50 or fare <= 15')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query('not fare >=50 and fare <= 90')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("sex=='male' & survived==1")
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query('''sex=='male' & survived==1''')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("sex=='male'").query('pclass==2')
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 17          1       2  male   NaN      0      0  13.0        S  Second  man
# 20          0       2  male  35.0      0      0  26.0        S  Second  man
# 21          1       2  male  34.0      0      0  13.0        S  Second  man
# 33          0       2  male  66.0      0      0  10.5        S  Second  man
# 70          0       2  male  32.0      0      0  10.5        S  Second  man
# ..        ...     ...   ...   ...    ...    ...   ...      ...     ...  ...
# 848         0       2  male  28.0      0      1  33.0        S  Second  man
# 861         0       2  male  21.0      1      0  11.5        S  Second  man
# 864         0       2  male  24.0      0      0  13.0        S  Second  man
# 883         0       2  male  28.0      0      0  10.5        S  Second  man
# 886         0       2  male  27.0      0      0  13.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
tt.query('''embark_town=='Southampton' or age>40 or sex=='male' and pclass==2 and fare>40 ''')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("embark_town=='Southampton'").query('age>40').query("sex=='male'")
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 35          0       1  male  42.0      1      0  52.0000        S   First
# 62          0       1  male  45.0      1      0  83.4750        S   First
# 92          0       1  male  46.0      1      0  61.1750        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 845         0       3  male  42.0      0      0   7.5500        S   Third
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 860         0       3  male  41.0      2      0  14.1083        S   Third
# 873         0       3  male  47.0      0      0   9.0000        S   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.query("embark_town=='Southampton'").query('age>40').query("sex=='male'").iloc[:10]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 35          0       1  male  42.0      1      0  52.0000        S   First
# 62          0       1  male  45.0      1      0  83.4750        S   First
# 92          0       1  male  46.0      1      0  61.1750        S   First
# 94          0       3  male  59.0      0      0   7.2500        S   Third
# 110         0       1  male  47.0      0      0  52.0000        S   First
# 124         0       1  male  54.0      0      1  77.2875        S   First
# 129         0       3  male  45.0      0      0   6.9750        S   Third
# 149         0       2  male  42.0      0      0  13.0000        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 6    man        True    E  Southampton    no   True
# ...

# %%
tt[(tt['age']>40) & (tt['fare']>40)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 35          0       1    male  42.0      1      0   52.0000        S   First
# 52          1       1  female  49.0      1      0   76.7292        C   First
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 62          0       1    male  45.0      1      0   83.4750        S   First
# 92          0       1    male  46.0      1      0   61.1750        S   First
# 110         0       1    male  47.0      0      0   52.0000        S   First
# 124         0       1    male  54.0      0      1   77.2875        S   First
# 155         0       1    male  51.0      0      1   61.3792        C   First
# 195         1       1  female  58.0      0      0  146.5208        C   First
# 245         0       1    male  44.0      2      0   90.0000        Q   First
# ...

# %%
tt[(tt['age']>40) & (tt['embark_town']=='Southampton')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 33          0       2    male  66.0      0      0  10.5000        S  Second
# 35          0       1    male  42.0      1      0  52.0000        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 860         0       3    male  41.0      2      0  14.1083        S   Third
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt[(tt['age']>40) & (tt['embark_town']=='Southampton')].iloc[:10]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 33          0       2    male  66.0      0      0  10.5000        S  Second
# 35          0       1    male  42.0      1      0  52.0000        S   First
# 62          0       1    male  45.0      1      0  83.4750        S   First
# 92          0       1    male  46.0      1      0  61.1750        S   First
# 94          0       3    male  59.0      0      0   7.2500        S   Third
# 110         0       1    male  47.0      0      0  52.0000        S   First
# 124         0       1    male  54.0      0      1  77.2875        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 6      man        True    E  Southampton    no   True
# ...

# %%
tt[(tt['age']>40) & (tt['embark_town']=='Southampton')].loc[:30]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 15         1       2  female  55.0      0      0  16.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True
# 15  woman       False  NaN  Southampton   yes   True

# %%
new_tt=tt[(tt['survived']==0)& (tt['pclass']==2)][['embark_town','alive']]

# %%
new_tt
# Out:
#      embark_town alive
# 20   Southampton    no
# 33   Southampton    no
# 41   Southampton    no
# 70   Southampton    no
# 72   Southampton    no
# ..           ...   ...
# 854  Southampton    no
# 861  Southampton    no
# 864  Southampton    no
# 883  Southampton    no
# 886  Southampton    no
#
# [97 rows x 2 columns]

# %%
new1_tt_alived=new_tt[(new_tt['alive']=='yes')]

# %%
#dataframe 형태

new1_tt_alived
# Out:
# Empty DataFrame
# Columns: [embark_town, alive]
# Index: []

# %%
new2_tt_alived=new_tt['alive']=='yes'

# %%
#series 형태

new2_tt_alived
# Out:
# 20     False
# 33     False
# 41     False
# 70     False
# 72     False
#        ...
# 854    False
# 861    False
# 864    False
# 883    False
# 886    False
# Name: alive, Length: 97, dtype: bool

# %%
tt.sort_values('fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
# ...

# %%
#먼저 입력한 column 기준으로 배열하는듯?

tt.sort_values(['fare','age'])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 302         0       3    male  19.0      0      0    0.0000        S  Third
# 271         1       3    male  25.0      0      0    0.0000        S  Third
# 179         0       3    male  36.0      0      0    0.0000        S  Third
# 822         0       1    male  38.0      0      0    0.0000        S  First
# 806         0       1    male  39.0      0      0    0.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.sort_values(['age','fare'])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 306         1       1  female   NaN      0      0  110.8833        C   First
# 334         1       1  female   NaN      1      0  133.6500        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 527         0       1    male   NaN      0      0  221.7792        S   First
# 557         0       1    male   NaN      0      0  227.5250        C   First
#
# ...

# %%
tt.sort_values(['age','fare'], ascending=[False,False])
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 481         0       2  male   NaN      0      0   0.0000        S  Second
# 633         0       1  male   NaN      0      0   0.0000        S   First
# 674         0       2  male   NaN      0      0   0.0000        S  Second
# 732         0       2  male   NaN      0      0   0.0000        S  Second
# 815         0       1  male   NaN      0      0   0.0000        S   First
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
sorting_tt=tt.sort_values(['age','fare']).query('age<50')

# %%
sorting_tt
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 803         1       3    male   0.42      0      1    8.5167        C   Third
# 755         1       2    male   0.67      1      1   14.5000        S  Second
# 469         1       3  female   0.75      2      1   19.2583        C   Third
# 644         1       3  female   0.75      2      1   19.2583        C   Third
# 831         1       2    male   0.83      1      1   18.7500        S  Second
# ..        ...     ...     ...    ...    ...    ...       ...      ...     ...
# 796         1       1  female  49.00      0      0   25.9292        S   First
# 599         1       1    male  49.00      1      0   56.9292        C   First
# 52          1       1  female  49.00      1      0   76.7292        C   First
# 453         1       1    male  49.00      1      0   89.1042        C   First
# 698         0       1    male  49.00      1      1  110.8833        C   First
#
# ...

# %%
sorting_tt1=sorting_tt.dropna()

# %%
sorting_tt1
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 340         1       2    male   2.00      1      1   26.0000        S  Second
# 297         0       1  female   2.00      1      2  151.5500        S   First
# ..        ...     ...     ...    ...    ...    ...       ...      ...     ...
# 796         1       1  female  49.00      0      0   25.9292        S   First
# 599         1       1    male  49.00      1      0   56.9292        C   First
# 52          1       1  female  49.00      1      0   76.7292        C   First
# 453         1       1    male  49.00      1      0   89.1042        C   First
# 698         0       1    male  49.00      1      1  110.8833        C   First
#
# ...

# %%
for i in sorting_tt1['embark_town']:
    if ['embark_town']=='Southampton':
        print('축구 근본 있는 지역')
    else:
        print('노근본 지역')

#southampton이 list에 있어서 결과가 나와야하는데...
# Out:
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# 노근본 지역
# ...

# %%
for i in sorting_tt1['age']:
    if i<=25:
        print('애기')
    else:
        print('늙은이')
# Out:
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 애기
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
# 늙은이
