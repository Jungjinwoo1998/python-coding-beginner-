# %% [markdown]
# ## 필수과제들
# - **필수과제1**
# -  q1 - pclass 3 이고, age 20세 미만인 남성과, 여성의 카운트 수와 생존수를 비교해 주세요.
#     - 코드와 데이터 값
#
# - **필수과제2**
# - 요금에 따라 3가지 등급으로 나눠주시고 (요금의 등급의 기준은 기초통계치 분위수 값으로 기준)
#     - 해당 분위수에 따라 남성과 여성을 추출하고 카운팅 수, 생존수 비교해 주세요.
#
# - **필수과제3**
# - 혼자온 사람과 혼자 오지 않은사람들 중에서 둘을 비교하는데
#     - 공통 조건은 혼자 온 사람의 성별 여부에 따른 전체 카운팅과 생존수 비교해 주세요!
#
#
# - 필수과제 요구조건
#     - 쥬피터노트북, 코드와 주석, 데이터 비교값을 공유

# %%
import seaborn as sns

# %%
tt=sns.load_dataset('titanic')

# %%
tt_pclass1=tt[tt['pclass']==1]

# %%
tt_pclass1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass1_male=tt_pclass1[tt_pclass1['sex']=='male']

# %%
tt_pclass1_male
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked  class  \
# 6           0       1  male  54.0      0      0   51.8625        S  First
# 23          1       1  male  28.0      0      0   35.5000        S  First
# 27          0       1  male  19.0      3      2  263.0000        S  First
# 30          0       1  male  40.0      0      0   27.7208        C  First
# 34          0       1  male  28.0      1      0   82.1708        C  First
# ..        ...     ...   ...   ...    ...    ...       ...      ...    ...
# 839         1       1  male   NaN      0      0   29.7000        C  First
# 857         1       1  male  51.0      0      0   26.5500        S  First
# 867         0       1  male  31.0      0      0   50.4958        S  First
# 872         0       1  male  33.0      0      0    5.0000        S  First
# 889         1       1  male  26.0      0      0   30.0000        C  First
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass1_female=tt_pclass1[tt_pclass1['sex']=='female']

# %%
tt_pclass1_female
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass2=tt[tt['pclass']==2]

# %%
tt_pclass2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass2_male=tt_pclass2[tt_pclass2['sex']=='male']

# %%
tt_pclass2_male
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 17          1       2  male   NaN      0      0  13.0        S  Second  man
# 20          0       2  male  35.0      0      0  26.0        S  Second  man
# 21          1       2  male  34.0      0      0  13.0        S  Second  man
# 33          0       2  male  66.0      0      0  10.5        S  Second  man
# 70          0       2  male  32.0      0      0  10.5        S  Second  man
# ..        ...     ...   ...   ...    ...    ...   ...      ...     ...  ...
# 848         0       2  male  28.0      0      1  33.0        S  Second  man
# 861         0       2  male  21.0      1      0  11.5        S  Second  man
# 864         0       2  male  24.0      0      0  13.0        S  Second  man
# 883         0       2  male  28.0      0      0  10.5        S  Second  man
# 886         0       2  male  27.0      0      0  13.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass2_female=tt_pclass2[tt_pclass2['sex']=='female']

# %%
tt_pclass2_female
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 41          0       2  female  27.0      1      0  21.0000        S  Second
# 43          1       2  female   3.0      1      2  41.5792        C  Second
# 53          1       2  female  29.0      1      0  26.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 854         0       2  female  44.0      1      0  26.0000        S  Second
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass3=tt[tt['pclass']==3]

# %%
tt_pclass3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass3_male=tt_pclass3[tt_pclass3['sex']=='male']

# %%
tt_pclass3_male
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3  male  22.0      1      0   7.2500        S  Third
# 4           0       3  male  35.0      0      0   8.0500        S  Third
# 5           0       3  male   NaN      0      0   8.4583        Q  Third
# 7           0       3  male   2.0      3      1  21.0750        S  Third
# 12          0       3  male  20.0      0      0   8.0500        S  Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...    ...
# 877         0       3  male  19.0      0      0   7.8958        S  Third
# 878         0       3  male   NaN      0      0   7.8958        S  Third
# 881         0       3  male  33.0      0      0   7.8958        S  Third
# 884         0       3  male  25.0      0      0   7.0500        S  Third
# 890         0       3  male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt_pclass3_female=tt_pclass3[tt_pclass3['sex']=='female']

# %%
tt_pclass3_female
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 8           1       3  female  27.0      0      2  11.1333        S  Third
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 14          0       3  female  14.0      0      0   7.8542        S  Third
# 18          0       3  female  31.0      1      0  18.0000        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 863         0       3  female   NaN      8      2  69.5500        S  Third
# 875         1       3  female  15.0      0      0   7.2250        C  Third
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ##결괏값
# - pclass1
#     남성:122명
#     여성:94명
#
# -pclass2
#     남성:184명
#     여성:108명
#
# -pclass3
#     남성:347명
#     여성:144명
