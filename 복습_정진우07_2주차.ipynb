# %%
import pandas as pd
import seaborn as sns

# %%
#attribute error: why does it occur?

data_ex1=pd.DataFrame({
    '학년':[2,3,4,1,1,2,2,3],
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '전공':['체육교육과','수학교육과','국어교육과','컴퓨터공학과','전자공학과','신소재공학과','철학과','경영학과']
})

# %%
data_ex1
# Out:
#    학년    학교      전공
# 0   2   한양대   체육교육과
# 1   3   고려대   수학교육과
# 2   4   세종대   국어교육과
# 3   1  성균관대  컴퓨터공학과
# 4   1   연세대   전자공학과
# 5   2   서울대  신소재공학과
# 6   2   경북대     철학과
# 7   3   부산대    경영학과

# %%
#attribute error: why does it occur?
#sol: 'DataFrame'

data_ex2=pd.DataFrame({
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '학년':[2,3,4,1,1,2,2,3],
    '나이':[21,22,27,20,19,23,24,22],
})

# %%
data_ex2
# Out:
#      학교  학년  나이
# 0   한양대   2  21
# 1   고려대   3  22
# 2   세종대   4  27
# 3  성균관대   1  20
# 4   연세대   1  19
# 5   서울대   2  23
# 6   경북대   2  24
# 7   부산대   3  22

# %%
tt=sns.load_dataset('titanic')

# %%
#셀을 순차적으로 실행해야 오류가 뜨지 않고 정상적으로 실행이 됨.

tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
tt[['age','embark_town','alive']]
# Out:
#       age  embark_town alive
# 0    22.0  Southampton    no
# 1    38.0    Cherbourg   yes
# 2    26.0  Southampton   yes
# 3    35.0  Southampton   yes
# 4    35.0  Southampton    no
# ..    ...          ...   ...
# 886  27.0  Southampton    no
# 887  19.0  Southampton   yes
# 888   NaN  Southampton    no
# 889  26.0    Cherbourg   yes
# 890  32.0   Queenstown    no
#
# [891 rows x 3 columns]

# %%
#keyerror?
#using only one bracket for obtaining at least two columns -> error

tt['age','embark_town','alive']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'embark_town', 'alive')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       1 #keyerror?
#       2 #using only one bracket for obtaining at least two columns -> error
# ----> 4 tt['age','embark_town','alive']
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('age', 'embark_town', 'alive')

# %%
tt['age']

# %%
type(tt)

# %%
tt[['age']]*100

# %%
#column(age) contains the value 'nan', then we have result 'nan'

sum(tt['age'])

# %%
list(tt)

# %%
type(list(tt))

# %%
pd.Series(tt['age'])

# %%
list(tt['age'])

# %%
type(pd.Series(tt['age']))

# %%
sum(tt['fare'])

# %%
tt[['fare']]

# %%
#mean value
sum(tt['fare'])/len(list(tt['age']))

# %%
max(tt['age'])

# %%
tt.head(10)

# %%
#이것도 가능
tt['pclass'].head()

# %%
tt[['pclass']].head()

# %%
#(row, column)
tt.shape

# %%
#int:정수형 데이터
#object:문자열, 객체형 데이터
#float:소수점 포함 연속형 데이터
#category:범주형 데이터
#bool:true/false
#dtype: object: 이 데이터 프레임의 자료형 정보가 object로 출력되었음을 의미

tt.dtypes

# %%
tt.info()

# %%
tt.describe()

# %%
#Inverting integer types
tt.describe().astype(int)

# %%
tt.describe(include='all').astype(object)

# %%
tt.describe(include='bool')

# %%
tt.columns

# %%
tt2=tt.copy()

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
tt2=tt2.rename(columns={'sex':'male/female'})

# %%
tt2
# Out:
#      survived  pclass male/female   age  sibsp  parch     fare embarked  \
# 0           0       3        male  22.0      1      0   7.2500        S
# 1           1       1      female  38.0      1      0  71.2833        C
# 2           1       3      female  26.0      0      0   7.9250        S
# 3           1       1      female  35.0      1      0  53.1000        S
# 4           0       3        male  35.0      0      0   8.0500        S
# ..        ...     ...         ...   ...    ...    ...      ...      ...
# 886         0       2        male  27.0      0      0  13.0000        S
# 887         1       1      female  19.0      0      0  30.0000        S
# 888         0       3      female   NaN      1      2  23.4500        S
# 889         1       1        male  26.0      0      0  30.0000        C
# 890         0       3        male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     First  woman       False    C  Southampton   yes  False
# 4     Third    man        True  NaN  Southampton    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
tt3=tt.copy()

# %%
tt3.rename(columns={'fare':'요금'}, inplace=True)

# %%
tt3
# Out:
#      survived  pclass     sex   age  sibsp  parch       요금 embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data_ex3=pd.DataFrame({
    '학년':[2,3,4,1,1,2,2,3],
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '전공':['체육교육과','수학교육과','국어교육과','컴퓨터공학과','전자공학과','신소재공학과','철학과','경영학과']
})

# %%
data_ex3
# Out:
#    학년    학교      전공
# 0   2   한양대   체육교육과
# 1   3   고려대   수학교육과
# 2   4   세종대   국어교육과
# 3   1  성균관대  컴퓨터공학과
# 4   1   연세대   전자공학과
# 5   2   서울대  신소재공학과
# 6   2   경북대     철학과
# 7   3   부산대    경영학과

# %%
data_ex4=data_ex3.copy()

# %%
data_ex4
# Out:
#    학년    학교      전공
# 0   2   한양대   체육교육과
# 1   3   고려대   수학교육과
# 2   4   세종대   국어교육과
# 3   1  성균관대  컴퓨터공학과
# 4   1   연세대   전자공학과
# 5   2   서울대  신소재공학과
# 6   2   경북대     철학과
# 7   3   부산대    경영학과

# %%
data_ex4=data_ex4.rename(columns={'전공':'학과'})

# %%
data_ex4
# Out:
#    학년    학교      학과
# 0   2   한양대   체육교육과
# 1   3   고려대   수학교육과
# 2   4   세종대   국어교육과
# 3   1  성균관대  컴퓨터공학과
# 4   1   연세대   전자공학과
# 5   2   서울대  신소재공학과
# 6   2   경북대     철학과
# 7   3   부산대    경영학과

# %%
data_ex5=pd.DataFrame({
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '학년':[2,3,4,1,1,2,2,3],
    '나이':[21,22,27,20,19,23,24,22],
})

# %%
data_ex5
# Out:
#      학교  학년  나이
# 0   한양대   2  21
# 1   고려대   3  22
# 2   세종대   4  27
# 3  성균관대   1  20
# 4   연세대   1  19
# 5   서울대   2  23
# 6   경북대   2  24
# 7   부산대   3  22

# %%
data_ex5['입학 나이']=data_ex5['나이']-data_ex5['학년']

# %%
data_ex5
# Out:
#      학교  학년  나이  입학 나이
# 0   한양대   2  21     19
# 1   고려대   3  22     19
# 2   세종대   4  27     23
# 3  성균관대   1  20     19
# 4   연세대   1  19     18
# 5   서울대   2  23     21
# 6   경북대   2  24     22
# 7   부산대   3  22     19

# %%
e=[]
for i in data_ex5['입학 나이']:
    if i<=19:
        e.append('현역/조기입학')
    else:
        e.append('N수생')

# %%
e
# Out:
# ['현역/조기입학', '현역/조기입학', 'N수생', '현역/조기입학', '현역/조기입학', 'N수생', 'N수생', '현역/조기입학']

# %%
data_ex6=data_ex5['입학 나이']

# %%
data_ex6
# Out:
# 0    19
# 1    19
# 2    23
# 3    19
# 4    18
# 5    21
# 6    22
# 7    19
# Name: 입학 나이, dtype: int64

# %%
c=[]
for i in data_ex6:
    if i<=19:
        c.append('현역/조기입학')
    else:
        c.append('N수생')

# %%
c
# Out:
# ['현역/조기입학', '현역/조기입학', 'N수생', '현역/조기입학', '현역/조기입학', 'N수생', 'N수생', '현역/조기입학']

# %%
import numpy as np

# %%
data_ex5
# Out:
#      학교  학년  나이  입학 나이
# 0   한양대   2  21     19
# 1   고려대   3  22     19
# 2   세종대   4  27     23
# 3  성균관대   1  20     19
# 4   연세대   1  19     18
# 5   서울대   2  23     21
# 6   경북대   2  24     22
# 7   부산대   3  22     19

# %%
data_ex5['N수생 여부']=np.where(data_ex5['입학 나이']<=19,'현역','N수생')

# %%
data_ex5['N수생 여부']
# Out:
# 0     현역
# 1     현역
# 2    N수생
# 3     현역
# 4     현역
# 5    N수생
# 6    N수생
# 7     현역
# Name: N수생 여부, dtype: object

# %%
data_ex5['N수생 여부'].value_counts()
# Out:
# N수생 여부
# 현역     5
# N수생    3
# Name: count, dtype: int64

# %%
data_ex5
# Out:
#      학교  학년  나이  입학 나이 N수생 여부
# 0   한양대   2  21     19     현역
# 1   고려대   3  22     19     현역
# 2   세종대   4  27     23    N수생
# 3  성균관대   1  20     19     현역
# 4   연세대   1  19     18     현역
# 5   서울대   2  23     21    N수생
# 6   경북대   2  24     22    N수생
# 7   부산대   3  22     19     현역

# %%
tt['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
tt.iloc[:10,0:4]
# Out:
#    survived  pclass     sex   age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0
# 5         0       3    male   NaN
# 6         0       1    male  54.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0
# 9         1       2  female  14.0

# %%
tt.loc[:10,['pclass','survived','age','sex']]
# Out:
#     pclass  survived   age     sex
# 0        3         0  22.0    male
# 1        1         1  38.0  female
# 2        3         1  26.0  female
# 3        1         1  35.0  female
# 4        3         0  35.0    male
# 5        3         0   NaN    male
# 6        1         0  54.0    male
# 7        3         0   2.0    male
# 8        3         1  27.0  female
# 9        2         1  14.0  female
# 10       3         1   4.0  female

# %%
tt.iloc[:10,[1,3]]
# Out:
#    pclass   age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0
# 5       3   NaN
# 6       1  54.0
# 7       3   2.0
# 8       3  27.0
# 9       2  14.0

# %%
#loc으로 하면 오류가 뜸
tt.loc[:10,[1,3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 2
#       1 #loc으로 하면 오류가 뜸
# ----> 2 tt.loc[:10,[1,3]]
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([1, 3], dtype='int32')] are in the [columns]"

# %%
tt['age'].loc[5]
# Out:
# nan

# %%
tt['age'].iloc[5]
# Out:
# nan

# %%
tt['fare'].loc[888]
# Out:
# 23.45

# %%
tt['fare'].iloc[888]
# Out:
# 23.45

# %%
tt_1=tt.tail()

# %%
tt_1
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
tt.loc[:10,['sex']]
# Out:
#        sex
# 0     male
# 1   female
# 2   female
# 3   female
# 4     male
# 5     male
# 6     male
# 7     male
# 8   female
# 9   female
# 10  female

# %%
tt.iloc[:10,['sex']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 tt.iloc[:10,['sex']]
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1608, in _iLocIndexer._validate_key(self, key, axis)
#    1606 # check that the key has a numeric dtype
#    1607 if not is_numeric_dtype(arr.dtype):
# -> 1608     raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1610 # check that the key does not exceed the maximum size of the index
#    1611 if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
#
# IndexError: .iloc requires numeric indexers, got ['sex']

# %%
tt_1.loc[889]
# Out:
# survived               1
# pclass                 1
# sex                 male
# age                 26.0
# sibsp                  0
# parch                  0
# fare                30.0
# embarked               C
# class              First
# who                  man
# adult_male          True
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone               True
# Name: 889, dtype: object

# %%
tt_1.iloc[890]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 tt_1.iloc[890]
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
