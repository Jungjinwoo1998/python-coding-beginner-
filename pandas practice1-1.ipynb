# %%
import pandas as pd
import seaborn as sns

# %%
#attribute error: why does it occur?

data_ex1=pd.Dataframe({
    '학년':[2,3,4,1,1,2,2,3],
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '전공':['체육교육과','수학교육과','국어교육과','컴퓨터공학과','전자공학과','신소재공학과','철학과','경영학과']
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 3
#       1 #attribute error: why does it occur?
# ----> 3 data_ex1=pd.Dataframe({
#       4     '학년':[2,3,4,1,1,2,2,3],
#       5     '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
#       6     '전공':['체육교육과','수학교육과','국어교육과','컴퓨터공학과','전자공학과','신소재공학과','철학과','경영학과']
#       7 })
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
data_ex1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 data_ex1
#
# NameError: name 'data_ex1' is not defined

# %%
#attribute error: why does it occur?
#sol: 'DataFrame'

data_ex2=pd.DataFrame({
    '학교':['한양대','고려대','세종대','성균관대','연세대','서울대','경북대','부산대'],
    '학년':[2,3,4,1,1,2,2,3],
    '나이':[21,22,27,20,19,23,24,22],
})

# %%
data_ex2
# Out:
#      학교  학년  나이
# 0   한양대   2  21
# 1   고려대   3  22
# 2   세종대   4  27
# 3  성균관대   1  20
# 4   연세대   1  19
# 5   서울대   2  23
# 6   경북대   2  24
# 7   부산대   3  22

# %%
tt=sns.load_dataset('titanic')

# %%
#셀을 순차적으로 실행해야 오류가 뜨지 않고 정상적으로 실행이 됨.

tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt[['age','embark_town','alive']]
# Out:
#       age  embark_town alive
# 0    22.0  Southampton    no
# 1    38.0    Cherbourg   yes
# 2    26.0  Southampton   yes
# 3    35.0  Southampton   yes
# 4    35.0  Southampton    no
# ..    ...          ...   ...
# 886  27.0  Southampton    no
# 887  19.0  Southampton   yes
# 888   NaN  Southampton    no
# 889  26.0    Cherbourg   yes
# 890  32.0   Queenstown    no
#
# [891 rows x 3 columns]

# %%
#keyerror?
#using only one bracket for obtaining at least two columns -> error

tt['age','embark_town','alive']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'embark_town', 'alive')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 4
#       1 #keyerror?
# ...

# %%
tt['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(tt)
# Out:
# pandas.core.frame.DataFrame

# %%
tt[['age']]*100
# Out:
#         age
# 0    2200.0
# 1    3800.0
# 2    2600.0
# 3    3500.0
# 4    3500.0
# ..      ...
# 886  2700.0
# 887  1900.0
# 888     NaN
# 889  2600.0
# 890  3200.0
#
# [891 rows x 1 columns]

# %%
#column(age) contains the value 'nan', then we have result 'nan'

sum(tt['age'])
# Out:
# nan

# %%
list(tt)
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
list(tt['age'])
# Out:
# [22.0,
#  38.0,
#  26.0,
#  35.0,
#  35.0,
#  nan,
#  54.0,
#  2.0,
#  27.0,
#  14.0,
#  4.0,
#  58.0,
#  20.0,
#  39.0,
#  14.0,
#  55.0,
#  2.0,
#  nan,
#  31.0,
#  nan,
#  35.0,
#  34.0,
#  15.0,
#  28.0,
#  8.0,
#  38.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  nan,
#  66.0,
#  28.0,
#  42.0,
#  nan,
#  21.0,
#  18.0,
#  14.0,
#  40.0,
#  27.0,
#  nan,
#  3.0,
#  19.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  18.0,
#  7.0,
#  21.0,
#  49.0,
#  29.0,
#  65.0,
#  nan,
#  21.0,
#  28.5,
#  5.0,
#  11.0,
#  22.0,
#  38.0,
#  45.0,
#  4.0,
#  nan,
#  nan,
#  29.0,
#  19.0,
#  17.0,
#  26.0,
#  32.0,
#  16.0,
#  21.0,
#  26.0,
#  32.0,
#  25.0,
#  nan,
#  nan,
#  0.83,
#  30.0,
#  22.0,
#  29.0,
#  nan,
#  28.0,
#  17.0,
#  33.0,
#  16.0,
#  nan,
#  23.0,
#  24.0,
#  29.0,
#  20.0,
#  46.0,
#  26.0,
#  59.0,
#  nan,
#  71.0,
#  23.0,
#  34.0,
#  34.0,
#  28.0,
#  nan,
#  21.0,
#  33.0,
#  37.0,
#  28.0,
#  21.0,
#  nan,
#  38.0,
#  nan,
#  47.0,
#  14.5,
#  22.0,
#  20.0,
# ...

# %%
type(list(tt))
# Out:
# list

# %%
pd.Series(tt['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(pd.Series(tt['age']))
# Out:
# pandas.core.series.Series

# %%
sum(tt['fare'])
# Out:
# 28693.9493

# %%
tt[['fare']]
# Out:
#         fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
#mean value
sum(tt['fare'])/len(list(tt['age']))
# Out:
# 32.204207968574636

# %%
max(tt['age'])
# Out:
# 80.0

# %%
tt.head(30)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
#이것도 가능
tt['pclass'].head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: int64

# %%
tt[['pclass']].head()
# Out:
#    pclass
# 0       3
# 1       1
# 2       3
# 3       1
# 4       3

# %%
#(row, column)
tt.shape
# Out:
# (891, 15)

# %%
#int:정수형 데이터
#object:문자열, 객체형 데이터
#float:소수점 포함 연속형 데이터
#category:범주형 데이터
#bool:true/false
#dtype: object: 이 데이터 프레임의 자료형 정보가 object로 출력되었음을 의미

tt.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Inverting integer types
tt.describe().astype(int)
# Out:
#        survived  pclass  age  sibsp  parch  fare
# count       891     891  714    891    891   891
# mean          0       2   29      0      0    32
# std           0       0   14      1      0    49
# min           0       1    0      0      0     0
# 25%           0       2   20      0      0     7
# 50%           0       3   28      0      0    14
# 75%           1       3   38      1      0    31
# max           1       3   80      8      6   512

# %%
tt.describe(include='all').astype(object)
# Out:
#         survived    pclass   sex        age     sibsp     parch       fare  \
# count      891.0     891.0   891      714.0     891.0     891.0      891.0
# unique       NaN       NaN     2        NaN       NaN       NaN        NaN
# top          NaN       NaN  male        NaN       NaN       NaN        NaN
# freq         NaN       NaN   577        NaN       NaN       NaN        NaN
# mean    0.383838  2.308642   NaN  29.699118  0.523008  0.381594  32.204208
# std     0.486592  0.836071   NaN  14.526497  1.102743  0.806057  49.693429
# min          0.0       1.0   NaN       0.42       0.0       0.0        0.0
# 25%          0.0       2.0   NaN     20.125       0.0       0.0     7.9104
# 50%          0.0       3.0   NaN       28.0       0.0       0.0    14.4542
# 75%          1.0       3.0   NaN       38.0       1.0       0.0       31.0
# max          1.0       3.0   NaN       80.0       8.0       6.0   512.3292
#
#        embarked  class  who adult_male deck  embark_town alive alone
# ...

# %%
tt.describe(include='bool')
# Out:
#        adult_male alone
# count         891   891
# unique          2     2
# top          True  True
# freq          537   537

# %%
tt.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
