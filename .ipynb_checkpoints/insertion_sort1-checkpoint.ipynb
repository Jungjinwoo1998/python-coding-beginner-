# %%
def find_idx22222(a,x):  #a is list, x is the element of the list
    l=len(a)
    for i in range (0,l):
        if x==a[i]:
            result=i
            
    return result
#그냥 단순하게 index만 찾아주는 함수이므로 적절치 않음.

# %%
b=[456,234,56,12,564]
find_idx22222(b,56)
# Out:
# 2

# %%
#실패
def ins_sort1(a):
    l=len(a)
    result=[]
    while a:
        result.append(a[0])
        a.pop(0)
        for j in range (0,l):
            result.append

# %%
def ins_sort2(a):
    l=len(a)
    result=[]
    for j in range (0,l):
        result.append(a[j])
