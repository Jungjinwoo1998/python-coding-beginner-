# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#loading csv file

train_df = pd.read_csv('train_1.csv')
test_df = pd.read_csv('test_1.csv')

# %%
train_df2=train_df

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
train_df = train_df.drop(['Age','Fare'], axis=1)
test_df = test_df.drop(['Age','Fare'], axis=1)
combine = [train_df, test_df]

# %%
combine
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex  SibSp  Parch  \
#  0                              Braund, Mr. Owen Harris    male      1      0
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
#  2                               Heikkinen, Miss. Laina  female      0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
#  4                             Allen, Mr. William Henry    male      0      0
#  ..                                                 ...     ...    ...    ...
#  886                              Montvila, Rev. Juozas    male      0      0
#  887                       Graham, Miss. Margaret Edith  female      0      0
#  888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
#  889                              Behr, Mr. Karl Howell    male      0      0
#  890                                Dooley, Mr. Patrick    male      0      0
#
#                 Ticket Cabin Embarked
#  0           A/5 21171   NaN        S
#  1            PC 17599   C85        C
#  2    STON/O2. 3101282   NaN        S
#  3              113803  C123        S
#  4              373450   NaN        S
#  ..                ...   ...      ...
#  886            211536   NaN        S
#  887            112053   B42        S
#  888        W./C. 6607   NaN        S
#  889            111369  C148        C
#  890            370376   NaN        Q
#
#  [891 rows x 10 columns],
#       PassengerId  Pclass                                          Name  \
#  0            892       3                              Kelly, Mr. James
#  1            893       3              Wilkes, Mrs. James (Ellen Needs)
#  2            894       2                     Myles, Mr. Thomas Francis
#  3            895       3                              Wirz, Mr. Albert
#  4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#  ..           ...     ...                                           ...
#  413         1305       3                            Spector, Mr. Woolf
#  414         1306       1                  Oliva y Ocana, Dona. Fermina
#  415         1307       3                  Saether, Mr. Simon Sivertsen
#  416         1308       3                           Ware, Mr. Frederick
#  417         1309       3                      Peter, Master. Michael J
#
#          Sex  SibSp  Parch              Ticket Cabin Embarked
#  0      male      0      0              330911   NaN        Q
#  1    female      1      0              363272   NaN        S
#  2      male      0      0              240276   NaN        Q
#  3      male      0      0              315154   NaN        S
#  4    female      1      1             3101298   NaN        S
#  ..      ...    ...    ...                 ...   ...      ...
#  413    male      0      0           A.5. 3236   NaN        S
#  414  female      0      0            PC 17758  C105        C
#  415    male      0      0  SOTON/O.Q. 3101262   NaN        S
#  416    male      0      0              359309   NaN        S
#  417    male      1      1                2668   NaN        C
#
#  [418 rows x 9 columns]]

# %%
for df in combine:
    df['Name_re'] = df.Name.str.extract(' ([A-Za-z]+).', expand=True)

# %%
pd.crosstab(train_df['Name_re'],train_df['Sex'])
# Out:
# Sex          female  male
# Name_re
# Billiard          0     1
# Capt              0     1
# Carlo             0     1
# Col               0     2
# Cruyssen          0     1
# Don               0     1
# Dr                1     6
# Gordon            1     1
# Impe              2     1
# Jonkheer          0     1
# Major             0     2
# Master            0    40
# Melkebeke         0     1
# Messemaeker       1     0
# Miss            179     0
# Mlle              2     0
# Mme               1     0
# Mr                0   502
# Mrs             121     0
# Ms                1     0
# Mulder            0     1
# Pelsmaeker        0     1
# Planke            2     1
# Rev               0     6
# Shawah            0     1
# Steen             0     1
# Velde             0     1
# Walle             0     1
# der               0     1
# the               1     0
# y                 2     2

# %%
for df in combine:
    df['Name_re'] = df['Name_re'].replace(['Lady','Countess','Col','Don','Dr','Major','Rev','Sir','Jonkheer','Dona'],'Rare')
    df['Name_re'] = df['Name_re'].replace('Mlle','Miss')
    df['Name_re'] = df['Name_re'].replace('Ms','Miss')
    df['Name_re'] = df['Name_re'].replace('Mme','Miss')

# %%
combine
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex  SibSp  Parch  \
#  0                              Braund, Mr. Owen Harris    male      1      0
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
#  2                               Heikkinen, Miss. Laina  female      0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
#  4                             Allen, Mr. William Henry    male      0      0
#  ..                                                 ...     ...    ...    ...
#  886                              Montvila, Rev. Juozas    male      0      0
#  887                       Graham, Miss. Margaret Edith  female      0      0
#  888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
#  889                              Behr, Mr. Karl Howell    male      0      0
#  890                                Dooley, Mr. Patrick    male      0      0
#
#                 Ticket Cabin Embarked Name_re
#  0           A/5 21171   NaN        S      Mr
#  1            PC 17599   C85        C     Mrs
#  2    STON/O2. 3101282   NaN        S    Miss
#  3              113803  C123        S     Mrs
#  4              373450   NaN        S      Mr
#  ..                ...   ...      ...     ...
#  886            211536   NaN        S    Rare
#  887            112053   B42        S    Miss
#  888        W./C. 6607   NaN        S    Miss
#  889            111369  C148        C      Mr
#  890            370376   NaN        Q      Mr
#
#  [891 rows x 11 columns],
#       PassengerId  Pclass                                          Name  \
#  0            892       3                              Kelly, Mr. James
#  1            893       3              Wilkes, Mrs. James (Ellen Needs)
#  2            894       2                     Myles, Mr. Thomas Francis
#  3            895       3                              Wirz, Mr. Albert
#  4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#  ..           ...     ...                                           ...
#  413         1305       3                            Spector, Mr. Woolf
#  414         1306       1                  Oliva y Ocana, Dona. Fermina
#  415         1307       3                  Saether, Mr. Simon Sivertsen
#  416         1308       3                           Ware, Mr. Frederick
#  417         1309       3                      Peter, Master. Michael J
#
#          Sex  SibSp  Parch              Ticket Cabin Embarked Name_re
#  0      male      0      0              330911   NaN        Q      Mr
#  1    female      1      0              363272   NaN        S     Mrs
#  2      male      0      0              240276   NaN        Q      Mr
#  3      male      0      0              315154   NaN        S      Mr
#  4    female      1      1             3101298   NaN        S     Mrs
#  ..      ...    ...    ...                 ...   ...      ...     ...
#  413    male      0      0           A.5. 3236   NaN        S      Mr
#  414  female      0      0            PC 17758  C105        C       y
#  415    male      0      0  SOTON/O.Q. 3101262   NaN        S      Mr
#  416    male      0      0              359309   NaN        S      Mr
#  417    male      1      1                2668   NaN        C  Master
#
#  [418 rows x 10 columns]]

# %%
train_df[['Name_re','Survived']].groupby(['Name_re'],as_index=False).mean()
# Out:
#         Name_re  Survived
# 0      Billiard  0.000000
# 1          Capt  0.000000
# 2         Carlo  0.000000
# 3      Cruyssen  0.000000
# 4        Gordon  1.000000
# 5          Impe  0.000000
# 6        Master  0.575000
# 7     Melkebeke  0.000000
# 8   Messemaeker  1.000000
# 9          Miss  0.710383
# 10           Mr  0.157371
# 11          Mrs  0.801653
# 12       Mulder  1.000000
# 13   Pelsmaeker  0.000000
# 14       Planke  0.000000
# 15         Rare  0.263158
# 16       Shawah  0.000000
# 17        Steen  0.000000
# 18        Velde  0.000000
# 19        Walle  0.000000
# 20          der  0.000000
# 21          the  1.000000
# 22            y  0.750000

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male      0      0
# 887                       Graham, Miss. Margaret Edith  female      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 889                              Behr, Mr. Karl Howell    male      0      0
# 890                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket Cabin Embarked Name_re
# 0           A/5 21171   NaN        S      Mr
# 1            PC 17599   C85        C     Mrs
# 2    STON/O2. 3101282   NaN        S    Miss
# 3              113803  C123        S     Mrs
# 4              373450   NaN        S      Mr
# ..                ...   ...      ...     ...
# 886            211536   NaN        S    Rare
# 887            112053   B42        S    Miss
# 888        W./C. 6607   NaN        S    Miss
# 889            111369  C148        C      Mr
# 890            370376   NaN        Q      Mr
#
# [891 rows x 11 columns]

# %%
name_re = {'Mr':1, 'Miss':2, 'Mrs':3, 'Master':4}

for df in combine:
    df['Name_re'] = df['Name_re'].map(name_re)
    df['Name_re'] = df['Name_re'].fillna(0)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male      0      0
# 887                       Graham, Miss. Margaret Edith  female      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 889                              Behr, Mr. Karl Howell    male      0      0
# 890                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket Cabin Embarked  Name_re
# 0           A/5 21171   NaN        S      1.0
# 1            PC 17599   C85        C      3.0
# 2    STON/O2. 3101282   NaN        S      2.0
# 3              113803  C123        S      3.0
# 4              373450   NaN        S      1.0
# ..                ...   ...      ...      ...
# 886            211536   NaN        S      0.0
# 887            112053   B42        S      2.0
# 888        W./C. 6607   NaN        S      2.0
# 889            111369  C148        C      1.0
# 890            370376   NaN        Q      1.0
#
# [891 rows x 11 columns]

# %%
train_df = train_df.drop(['Name','PassengerId'], axis=1)
test_df = test_df.drop(['Name'], axis=1)
combine = [train_df, test_df]

# %%
combine
# Out:
# [     Survived  Pclass     Sex  SibSp  Parch            Ticket Cabin Embarked  \
#  0           0       3    male      1      0         A/5 21171   NaN        S
#  1           1       1  female      1      0          PC 17599   C85        C
#  2           1       3  female      0      0  STON/O2. 3101282   NaN        S
#  3           1       1  female      1      0            113803  C123        S
#  4           0       3    male      0      0            373450   NaN        S
#  ..        ...     ...     ...    ...    ...               ...   ...      ...
#  886         0       2    male      0      0            211536   NaN        S
#  887         1       1  female      0      0            112053   B42        S
#  888         0       3  female      1      2        W./C. 6607   NaN        S
#  889         1       1    male      0      0            111369  C148        C
#  890         0       3    male      0      0            370376   NaN        Q
#
#       Name_re
#  0        1.0
#  1        3.0
#  2        2.0
#  3        3.0
#  4        1.0
#  ..       ...
#  886      0.0
#  887      2.0
#  888      2.0
#  889      1.0
#  890      1.0
#
#  [891 rows x 9 columns],
#       PassengerId  Pclass     Sex  SibSp  Parch              Ticket Cabin  \
#  0            892       3    male      0      0              330911   NaN
#  1            893       3  female      1      0              363272   NaN
#  2            894       2    male      0      0              240276   NaN
#  3            895       3    male      0      0              315154   NaN
#  4            896       3  female      1      1             3101298   NaN
#  ..           ...     ...     ...    ...    ...                 ...   ...
#  413         1305       3    male      0      0           A.5. 3236   NaN
#  414         1306       1  female      0      0            PC 17758  C105
#  415         1307       3    male      0      0  SOTON/O.Q. 3101262   NaN
#  416         1308       3    male      0      0              359309   NaN
#  417         1309       3    male      1      1                2668   NaN
#
#      Embarked  Name_re
#  0          Q      1.0
#  1          S      3.0
#  2          Q      1.0
#  3          S      1.0
#  4          S      3.0
#  ..       ...      ...
#  413        S      1.0
#  414        C      0.0
#  415        S      1.0
#  416        S      1.0
#  417        C      4.0
#
#  [418 rows x 9 columns]]

# %%
for df in combine:
    df['Sex'] = df['Sex'].map({'female':1, 'male':0}).astype(int)

# %%
train_df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Cabin       687
# Embarked      2
# Name_re       0
# dtype: int64

# %%
train_df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
grid = sns.FacetGrid(train_df2, row='Pclass', col='Sex', aspect =1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] +1

# %%
combine
# Out:
# [     Survived  Pclass  Sex  SibSp  Parch            Ticket Cabin Embarked  \
#  0           0       3    0      1      0         A/5 21171   NaN        S
#  1           1       1    1      1      0          PC 17599   C85        C
#  2           1       3    1      0      0  STON/O2. 3101282   NaN        S
#  3           1       1    1      1      0            113803  C123        S
#  4           0       3    0      0      0            373450   NaN        S
#  ..        ...     ...  ...    ...    ...               ...   ...      ...
#  886         0       2    0      0      0            211536   NaN        S
#  887         1       1    1      0      0            112053   B42        S
#  888         0       3    1      1      2        W./C. 6607   NaN        S
#  889         1       1    0      0      0            111369  C148        C
#  890         0       3    0      0      0            370376   NaN        Q
#
#       Name_re  FamilySize
#  0        1.0           2
#  1        3.0           2
#  2        2.0           1
#  3        3.0           2
#  4        1.0           1
#  ..       ...         ...
#  886      0.0           1
#  887      2.0           1
#  888      2.0           4
#  889      1.0           1
#  890      1.0           1
#
#  [891 rows x 10 columns],
#       PassengerId  Pclass  Sex  SibSp  Parch              Ticket Cabin  \
#  0            892       3    0      0      0              330911   NaN
#  1            893       3    1      1      0              363272   NaN
#  2            894       2    0      0      0              240276   NaN
#  3            895       3    0      0      0              315154   NaN
#  4            896       3    1      1      1             3101298   NaN
#  ..           ...     ...  ...    ...    ...                 ...   ...
#  413         1305       3    0      0      0           A.5. 3236   NaN
#  414         1306       1    1      0      0            PC 17758  C105
#  415         1307       3    0      0      0  SOTON/O.Q. 3101262   NaN
#  416         1308       3    0      0      0              359309   NaN
#  417         1309       3    0      1      1                2668   NaN
#
#      Embarked  Name_re  FamilySize
#  0          Q      1.0           1
#  1          S      3.0           2
#  2          Q      1.0           1
#  3          S      1.0           1
#  4          S      3.0           3
#  ..       ...      ...         ...
#  413        S      1.0           1
#  414        C      0.0           1
#  415        S      1.0           1
#  416        S      1.0           1
#  417        C      4.0           3
#
#  [418 rows x 10 columns]]

# %%
#making dataset with columns 'familysize' and 'survived'
#organizing 'familysize' first and 'survived' after that

for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] +1

combine[0][['FamilySize','Survived']].groupby(['FamilySize'],as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
#making new column 'isalone'

for dataset in combine:
    dataset['IsAlone'] =0
    dataset.loc[dataset['FamilySize']==1 , 'IsAlone'] =1

# %%
combine[0][['IsAlone','Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
combine
# Out:
# [     Survived  Pclass  Sex  SibSp  Parch            Ticket Cabin Embarked  \
#  0           0       3    0      1      0         A/5 21171   NaN        S
#  1           1       1    1      1      0          PC 17599   C85        C
#  2           1       3    1      0      0  STON/O2. 3101282   NaN        S
#  3           1       1    1      1      0            113803  C123        S
#  4           0       3    0      0      0            373450   NaN        S
#  ..        ...     ...  ...    ...    ...               ...   ...      ...
#  886         0       2    0      0      0            211536   NaN        S
#  887         1       1    1      0      0            112053   B42        S
#  888         0       3    1      1      2        W./C. 6607   NaN        S
#  889         1       1    0      0      0            111369  C148        C
#  890         0       3    0      0      0            370376   NaN        Q
#
#       Name_re  FamilySize  IsAlone
#  0        1.0           2        0
#  1        3.0           2        0
#  2        2.0           1        1
#  3        3.0           2        0
#  4        1.0           1        1
#  ..       ...         ...      ...
#  886      0.0           1        1
#  887      2.0           1        1
#  888      2.0           4        0
#  889      1.0           1        1
#  890      1.0           1        1
#
#  [891 rows x 11 columns],
#       PassengerId  Pclass  Sex  SibSp  Parch              Ticket Cabin  \
#  0            892       3    0      0      0              330911   NaN
#  1            893       3    1      1      0              363272   NaN
#  2            894       2    0      0      0              240276   NaN
#  3            895       3    0      0      0              315154   NaN
#  4            896       3    1      1      1             3101298   NaN
#  ..           ...     ...  ...    ...    ...                 ...   ...
#  413         1305       3    0      0      0           A.5. 3236   NaN
#  414         1306       1    1      0      0            PC 17758  C105
#  415         1307       3    0      0      0  SOTON/O.Q. 3101262   NaN
#  416         1308       3    0      0      0              359309   NaN
#  417         1309       3    0      1      1                2668   NaN
#
#      Embarked  Name_re  FamilySize  IsAlone
#  0          Q      1.0           1        1
#  1          S      3.0           2        0
#  2          Q      1.0           1        1
#  3          S      1.0           1        1
#  4          S      3.0           3        0
#  ..       ...      ...         ...      ...
#  413        S      1.0           1        1
#  414        C      0.0           1        1
#  415        S      1.0           1        1
#  416        S      1.0           1        1
#  417        C      4.0           3        0
#
#  [418 rows x 11 columns]]

# %%
combine[1]
# Out:
#      PassengerId  Pclass  Sex  SibSp  Parch              Ticket Cabin  \
# 0            892       3    0      0      0              330911   NaN
# 1            893       3    1      1      0              363272   NaN
# 2            894       2    0      0      0              240276   NaN
# 3            895       3    0      0      0              315154   NaN
# 4            896       3    1      1      1             3101298   NaN
# ..           ...     ...  ...    ...    ...                 ...   ...
# 413         1305       3    0      0      0           A.5. 3236   NaN
# 414         1306       1    1      0      0            PC 17758  C105
# 415         1307       3    0      0      0  SOTON/O.Q. 3101262   NaN
# 416         1308       3    0      0      0              359309   NaN
# 417         1309       3    0      1      1                2668   NaN
#
#     Embarked  Name_re  FamilySize  IsAlone
# 0          Q      1.0           1        1
# 1          S      3.0           2        0
# 2          Q      1.0           1        1
# 3          S      1.0           1        1
# 4          S      3.0           3        0
# ..       ...      ...         ...      ...
# 413        S      1.0           1        1
# 414        C      0.0           1        1
# 415        S      1.0           1        1
# 416        S      1.0           1        1
# 417        C      4.0           3        0
#
# [418 rows x 11 columns]

# %%
combine = [train_df,test_df]

# %%
combine
# Out:
# [     Survived  Pclass  Sex  SibSp  Parch            Ticket Cabin Embarked  \
#  0           0       3    0      1      0         A/5 21171   NaN        S
#  1           1       1    1      1      0          PC 17599   C85        C
#  2           1       3    1      0      0  STON/O2. 3101282   NaN        S
#  3           1       1    1      1      0            113803  C123        S
#  4           0       3    0      0      0            373450   NaN        S
#  ..        ...     ...  ...    ...    ...               ...   ...      ...
#  886         0       2    0      0      0            211536   NaN        S
#  887         1       1    1      0      0            112053   B42        S
#  888         0       3    1      1      2        W./C. 6607   NaN        S
#  889         1       1    0      0      0            111369  C148        C
#  890         0       3    0      0      0            370376   NaN        Q
#
#       Name_re  FamilySize  IsAlone
#  0        1.0           2        0
#  1        3.0           2        0
#  2        2.0           1        1
#  3        3.0           2        0
#  4        1.0           1        1
#  ..       ...         ...      ...
#  886      0.0           1        1
#  887      2.0           1        1
#  888      2.0           4        0
#  889      1.0           1        1
#  890      1.0           1        1
#
#  [891 rows x 11 columns],
#       PassengerId  Pclass  Sex  SibSp  Parch              Ticket Cabin  \
#  0            892       3    0      0      0              330911   NaN
#  1            893       3    1      1      0              363272   NaN
#  2            894       2    0      0      0              240276   NaN
#  3            895       3    0      0      0              315154   NaN
#  4            896       3    1      1      1             3101298   NaN
#  ..           ...     ...  ...    ...    ...                 ...   ...
#  413         1305       3    0      0      0           A.5. 3236   NaN
#  414         1306       1    1      0      0            PC 17758  C105
#  415         1307       3    0      0      0  SOTON/O.Q. 3101262   NaN
#  416         1308       3    0      0      0              359309   NaN
#  417         1309       3    0      1      1                2668   NaN
#
#      Embarked  Name_re  FamilySize  IsAlone
#  0          Q      1.0           1        1
#  1          S      3.0           2        0
#  2          Q      1.0           1        1
#  3          S      1.0           1        1
#  4          S      3.0           3        0
#  ..       ...      ...         ...      ...
#  413        S      1.0           1        1
#  414        C      0.0           1        1
#  415        S      1.0           1        1
#  416        S      1.0           1        1
#  417        C      4.0           3        0
#
#  [418 rows x 11 columns]]

# %%
freq_value=train_df['Embarked'].dropna().mode()[0]

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_value)
#replacing NAs with lowest frequency embarked data


train_df[['Embarked','Survived']].groupby(['Embarked'],as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
train_df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# SibSp           0
# Parch           0
# Ticket          0
# Cabin         687
# Embarked        0
# Name_re         0
# FamilySize      0
# IsAlone         0
# dtype: int64
